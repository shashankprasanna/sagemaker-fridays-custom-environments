# %%
import boto3
sess = boto3.Session()
s3 = boto3.resource('s3')

# %%
ecr_repo_name = 'custom-dl-containers'

region = boto3.Session().region_name
account = boto3.client('sts').get_caller_identity().get('Account')
image_eks_cpu = '{}.dkr.ecr.{}.amazonaws.com/{}:eks-cpu'.format(account, region, ecr_repo_name)
image_eks_gpu = '{}.dkr.ecr.{}.amazonaws.com/{}:eks-gpu'.format(account, region, ecr_repo_name)
image_sm_gpu = '{}.dkr.ecr.{}.amazonaws.com/{}:sm-gpu'.format(account, region, ecr_repo_name)

# %%
# !aws ecr create-repository --repository-name {ecr_repo_name}
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
#
# An error occurred (RepositoryAlreadyExistsException) when calling the CreateRepository operation: The repository with name 'custom-dl-containers' already exists in the registry with id '453691756499'

# %%
# !aws ecr get-login-password --region us-west-2 | docker login --username AWS --password-stdin 763104351884.dkr.ecr.us-west-2.amazonaws.com
# !docker build -t {ecr_repo_name}:eks-cpu -f Dockerfile.ekscpu .
# !docker build -t {ecr_repo_name}:eks-gpu -f Dockerfile.eksgpu .
# !docker build -t {ecr_repo_name}:sm-gpu -f Dockerfile.smgpu .
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# WARNING! Your password will be stored unencrypted in /home/ubuntu/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# Sending build context to Docker daemon  60.42kB
# Step 1/3 : FROM 763104351884.dkr.ecr.us-west-2.amazonaws.com/tensorflow-training:2.8.0-cpu-py39-ubuntu20.04-e3
#  ---> 7140ced63766
# Step 2/3 : COPY tf2_cifar10_eks.py /opt/ml/code/tf2_cifar10_eks.py
#  ---> Using cache
#  ---> 4dde08a55ef5
# Step 3/3 : ENTRYPOINT ["python", "/opt/ml/code/tf2_cifar10_eks.py"]
#  ---> Using cache
#  ---> 63df701318b8
# Successfully built 63df701318b8
# Successfully tagged custom-dl-containers:eks-cpu
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# Sending build context to Docker daemon  60.42kB
# Step 1/3 : FROM 763104351884.dkr.ecr.us-west-2.amazonaws.com/tensorflow-training:2.8.0-gpu-py39-cu112-ubuntu20.04-e3
#  ---> 64aa64800002
# Step 2/3 : COPY tf2_cifar10_eks.py /opt/ml/code/tf2_cifar10_eks.py
#  ---> Using cache
#  ---> 13a9c4276d2e
# Step 3/3 : ENTRYPOINT ["python", "/opt/ml/code/tf2_cifar10_eks.py"]
#  ---> Using cache
#  ---> 5ec6093fbbe7
# Successfully built 5ec6093fbbe7
# Successfully tagged custom-dl-containers:eks-gpu
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# Sending build context to Docker daemon  60.42kB
# Step 1/3 : FROM 763104351884.dkr.ecr.us-west-2.amazonaws.com/tensorflow-training:2.8.0-gpu-py39-cu112-ubuntu20.04-sagemaker
#  ---> 8bfce0b7e5e6
# Step 2/3 : COPY tf2_cifar10_sm.py /opt/ml/code/tf2_cifar10_sm.py
#  ---> 314d53ee04cc
# Step 3/3 : ENTRYPOINT ["python", "/opt/ml/code/tf2_cifar10_sm.py"]
#  ---> Running in 5807c86cc629
# Removing intermediate container 5807c86cc629
#  ---> af4f87579743
# Successfully built af4f87579743
# Successfully tagged custom-dl-containers:sm-gpu

# %%
# !$(aws ecr get-login --no-include-email --region {region})

# !docker tag {ecr_repo_name}:eks-cpu {image_eks_cpu}
# !docker push {image_eks_cpu}

# !docker tag {ecr_repo_name}:eks-gpu {image_eks_gpu}
# !docker push {image_eks_gpu}

# !docker tag {ecr_repo_name}:sm-gpu {image_sm_gpu}
# !docker push {image_sm_gpu}
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ubuntu/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# The push refers to repository [453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers]
#
# 6685b78c: Preparing
# 719bd773: Preparing
# 7792f383: Preparing
# 280250b5: Preparing
# e42e91a1: Preparing
# c3660d39: Preparing
# 5a21cc99: Preparing
# 4354b2d6: Preparing
# 72fc637b: Preparing
# 1b729c68: Preparing
# 688a0ba7: Preparing
# 764be8aa: Preparing
# d727353c: Preparing
# c09fef95: Preparing
# eb2119f7: Preparing
# 8f91bb55: Preparing
# 690cbc0e: Preparing
# 4100c5d0: Preparing
# 4a320d57: Preparing
# 4a320d57: Layer already exists eks-cpu: digest: sha256:ef70b13fda98162fbda12a0aedb7b461d606e9b80de095476ab324f4b5bd8ab8 size: 4515
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# The push refers to repository [453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers]
#
# 6685b78c: Preparing
# 852f34e0: Preparing
# 663ed003: Preparing
# abb710b3: Preparing
# 1ee3d549: Preparing
# da410283: Preparing
# 92a44f3a: Preparing
# 12925889: Preparing
# 520a706c: Preparing
# 62457e7b: Preparing
# 24a0e363: Preparing
# 061fee57: Preparing
# a1526c65: Preparing
# da410283: Waiting g
# fa4b4284: Preparing
# 2a44f3a: Waiting g
# 2925889: Waiting g
# cd140df8: Preparing
# 061fee57: Waiting g
# 2457e7b: Waiting g
# a1526c65: Waiting g
# e3ad789e: Preparing
# f8cb8ee7: Waiting g
# fa9883b1: Preparing
# cd140df8: Waiting g
# 54add80b: Preparing
# 5d5700c: Waiting g
# a27e0d74: Preparing
# 55f71392: Preparing
# 1da349fd: Preparing
# 1da349fd: Layer already exists eks-gpu: digest: sha256:8f9a0c08965705ac90bf2d0c88880f43392b38a2f7b4a2030e8b9025b6cb2d9e size: 6825
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# The push refers to repository [453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers]
#
# 0b2fdea7: Preparing
# 965ed983: Preparing
# 8835f60f: Preparing
# 9d44bde7: Preparing
# fe5f2efd: Preparing
# a11c09d7: Preparing
# 76033b78: Preparing
# bc8583d3: Preparing
# 68989bbe: Preparing
# e1e154d9: Preparing
# 842f2efe: Preparing
# b4ed4231: Preparing
# 6f80e94b: Preparing
# 0d7d5fbc: Preparing
# f992d50a: Preparing
# 6033b78: Waiting g
# 866a2a0f: Preparing
# 0f1d92fb: Preparing
# 1e154d9: Waiting g
# c8583d3: Waiting g
# 1a8f5953: Preparing
# b616db33: Preparing
# a6fb0b0d: Preparing
# 4ed4231: Waiting g
# fbe172f3: Preparing
# c3a39a19: Preparing
# 66a2a0f: Waiting g
# fff30f0b: Preparing
# d7d5fbc: Waiting g
# e4f6839a: Preparing
# 992d50a: Waiting g
# f1d92fb: Waiting g
# 6d307cc: Waiting g
# 1850e143: Preparing
# 5d6fa3e: Waiting g
# 884a1ac8: Preparing
# 2561b10e: Preparing
# a650081: Waiting g
# ff30f0b: Waiting g
# 1da349fd: Preparing
# 55f71392: Layer already exists 5kB9Asm-gpu: digest: sha256:35569f8cb9bfa2fd708a452f4d3fc29cda06c045d441d75f1dc12924d692ac09 size: 8933

# %%
# !docker images
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# REPOSITORY                                                          TAG                                          IMAGE ID       CREATED         SIZE
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   sm-gpu                                       af4f87579743   5 seconds ago   10.3GB
# custom-dl-containers                                                sm-gpu                                       af4f87579743   5 seconds ago   10.3GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       6d132761750f   6 hours ago     10.3GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   eks-gpu                                      5ec6093fbbe7   6 hours ago     9.24GB
# custom-dl-containers                                                eks-gpu                                      5ec6093fbbe7   6 hours ago     9.24GB
# custom-dl-containers                                                eks-cpu                                      63df701318b8   6 hours ago     2.9GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   eks-cpu                                      63df701318b8   6 hours ago     2.9GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       40722e9c76c2   6 hours ago     2.9GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       668f1ba3f070   6 hours ago     9.24GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       3d936a0d75cb   6 hours ago     10.3GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       bc11398f5ebb   6 hours ago     9.24GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       efabb5315aa2   6 hours ago     2.9GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       e84388cb5817   6 hours ago     2.9GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       7c9dd875bb62   6 hours ago     9.24GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       6cbf4b86fedc   6 hours ago     9.24GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       244a02110f1d   6 hours ago     2.9GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       d5820cc2badd   6 hours ago     9.24GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       6d5b057c6476   6 hours ago     2.9GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       d9c53227bfff   6 hours ago     2.9GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       ae357ad864af   6 hours ago     9.24GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       3d107a38e7eb   7 hours ago     9.24GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       6fcc08a7ccca   7 hours ago     2.9GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       520082b533b1   7 hours ago     10.3GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       80ebc4ae043c   7 hours ago     10.3GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       adc2b39ada30   7 hours ago     10.3GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       00158156df42   7 hours ago     9.24GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       3b8948f2778f   7 hours ago     2.9GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       5ef00548b0b1   7 hours ago     9.24GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       d8935090b588   7 hours ago     10.3GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       8e51630809c5   7 hours ago     2.9GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       97ace4943dad   7 hours ago     10.3GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       2e8e26d0896c   7 hours ago     9.24GB
# 453691756499.dkr.ecr.us-west-2.amazonaws.com/custom-dl-containers   <none>                                       7ed90e159120   7 hours ago     2.9GB
# 763104351884.dkr.ecr.us-west-2.amazonaws.com/tensorflow-training    2.8.0-gpu-py39-cu112-ubuntu20.04-sagemaker   8bfce0b7e5e6   5 weeks ago     10.3GB
# 763104351884.dkr.ecr.us-west-2.amazonaws.com/tensorflow-training    2.8.0-cpu-py39-ubuntu20.04-e3                7140ced63766   6 weeks ago     2.9GB
# 763104351884.dkr.ecr.us-west-2.amazonaws.com/tensorflow-training    2.8.0-gpu-py39-cu112-ubuntu20.04-e3          64aa64800002   6 weeks ago     9.24GB
